# %% [markdown]
# # Reward-Conditioned Neural Memory Layer — Kaggle Quickstart
#
# **Runtime:** GPU (T4 16 GB is sufficient for cells 1–8)
# **Run cells IN ORDER. Do not skip any cell.**
#
# | Cell | Step | Gate |
# |---|---|---|
# | 1 | Install deps + create dirs | — |
# | 2 | Copy src files from dataset | — |
# | 3 | Isolation tests (CPU) | All 5 must PASS |
# | 4 | Load Gemma 2B | Model generates coherent Python |
# | 5 | Inject memory + perplexity check | Delta < 1% |
# | 6 | Sandbox smoke tests | All assertions pass |
# | 7 | Download + calibrate HumanEval | ≥1 problem in 30–60% range |
# | 8 | 3-problem smoke session | Loop runs, .pt checkpoint saved |
# | 9 | Full 5-session evaluation | improvement-on-failed > 30% |
# | 10 | Zip + download checkpoint | Before session expires |

# %%
# ── CELL 1: Install dependencies + create directory structure ──
import subprocess, sys
subprocess.run(
    [sys.executable, "-m", "pip", "install", "-q",
     "accelerate", "datasets", "faiss-cpu"],
    check=True
)

import os, json, torch
from pathlib import Path

sys.path.insert(0, "/kaggle/working/src")

for d in ["src", "problems", "memory_states", "results", "logs"]:
    Path(f"/kaggle/working/{d}").mkdir(parents=True, exist_ok=True)

print("Env ready. CUDA:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 81.3 MB/s eta 0:00:00
# Env ready. CUDA: True
# Device: Tesla T4

# %%
# ── CELL 2: Copy source files from uploaded Kaggle dataset ──
# Upload the src/ folder as a Kaggle dataset named 'memory-agent'.
# It will appear at /kaggle/input/memory-agent/src/

import shutil

SOURCE = "/kaggle/input/datasets/atromixtheanalyzer/memory-agent/src"  # adjust if your dataset name differs
DEST   = "/kaggle/working/src"

if os.path.exists(SOURCE):
    for f in os.listdir(SOURCE):
        shutil.copy(os.path.join(SOURCE, f), os.path.join(DEST, f))
    print("Source files copied:", os.listdir(DEST))
else:
    print(f"WARNING: {SOURCE} not found.")
    print("Upload the src/ folder as a Kaggle dataset, or copy files manually.")
    print("Required: memory_module.py, model_surgery.py, sandbox.py,")
    print("          session_manager.py, eval.py")
# Out:
# Source files copied: ['memory_module.py', 'sandbox.py', 'eval.py', 'model_surgery.py', 'session_manager.py']

# %%
# ── CELL 3: Isolation tests (CPU — no GPU needed) ──
# Step 2 from README_PROTOTYPE.md.
# ALL 5 tests must PASS before loading the LLM.
# If any FAIL, fix the issue in memory_module.py and re-run this cell.

from memory_module import run_all_isolation_tests
run_all_isolation_tests()
# Out:
# Running isolation tests on NeuralMemoryModule...
# (All must pass before attaching to any LLM)
#
#   PASS associative_storage: retrieval_error=0.0843
#   PASS surprise_decay: 2.2200 -> 1.2913
#   PASS reward_learning: all 3 pairs within 0.15 tolerance
#   PASS generalisation: base=0.97, similar=0.95, diff=0.10
#   PASS weight_norm_stability: 12.326 -> 8.355 (no NaN/Inf, retained >68% of initial norm)
#          post-stress retrieval error: 0.1317 (functional: YES)
#
# All isolation tests passed. Safe to proceed to LLM integration.

# %%
# ── CELL 4: Load Gemma 2B ──
# Steps 1 + 3 (load base model, verify it generates coherent Python).

from transformers import AutoModelForCausalLM, AutoTokenizer
from huggingface_hub import login

import os
HF_TOKEN = os.environ.get("HF_TOKEN", "YOUR_HF_TOKEN")
MODEL_ID = "google/gemma-2-2b-it"

login(token=HF_TOKEN, add_to_git_credential=False)

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float16,
    device_map="auto"
)
print("Model loaded. Device:", next(model.parameters()).device)

# Milestone check: should produce coherent Python
inputs = tokenizer(
    "Write a Python function to reverse a string:",
    return_tensors="pt"
).to("cuda")
out = model.generate(**inputs, max_new_tokens=80, temperature=0.1)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/288 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Model loaded. Device: cuda:0
# Write a Python function to reverse a string:
#
# ```python
# def reverse_string(s):
#   """
#   Reverses a string.
#
#   Args:
#     s: The string to reverse.
#
#   Returns:
#     The reversed string.
#   """
#   return s[::-1]
# ```
#
# **Explanation:**
#
# * **`def reverse_string(s):`**: This line defines a function named `

# %%
# ── CELL 5: Inject memory layers + perplexity gate check ──
# Step 3 from README_PROTOTYPE.md.
# Perplexity delta must be < 1% — if higher, gate.bias is not -5.0.

from model_surgery import inject_memory_layers, measure_perplexity

VALIDATION_TEXTS = [
    "def add(a, b):\n    return a + b",
    "def reverse(s):\n    return s[::-1]",
    "for i in range(10):\n    print(i)",
    "x = [1, 2, 3]\nx.sort()\nprint(x)",
    "def is_prime(n):\n    return n > 1 and all(n % i for i in range(2, n))",
    "import os\nprint(os.getcwd())",
    "d = {'a': 1, 'b': 2}\nprint(d.get('a', 0))",
    "result = [x**2 for x in range(5)]",
    "def fib(n):\n    return n if n < 2 else fib(n-1) + fib(n-2)",
    "with open('test.txt', 'w') as f:\n    f.write('hello')",
]

ppl_before = measure_perplexity(model, tokenizer, VALIDATION_TEXTS)
print(f"Perplexity before injection: {ppl_before:.4f}")

MEMORY_LAYERS = [4, 8, 16, 24]
model, memory_modules = inject_memory_layers(model, MEMORY_LAYERS)

ppl_after = measure_perplexity(model, tokenizer, VALIDATION_TEXTS)
delta_pct = abs(ppl_after - ppl_before) / ppl_before * 100
print(f"Perplexity after injection:  {ppl_after:.4f}")
print(f"Delta: {delta_pct:.2f}%  (must be < 1% to proceed)")

assert delta_pct < 1.0, (
    f"FAIL: perplexity degraded by {delta_pct:.2f}%. "
    "Check gate.bias init (should be -5.0)."
)
print("\nGate OK. Safe to proceed.")
# Out:
# Perplexity before injection: 1.8748
#   Memory injected at layer 4 (device=cuda:0, dtype=torch.float16)
#   Memory injected at layer 8 (device=cuda:0, dtype=torch.float16)
#   Memory injected at layer 16 (device=cuda:1, dtype=torch.float16)
#   Memory injected at layer 24 (device=cuda:1, dtype=torch.float16)
#   Trainable: 191,158,280 / 2,805,500,168 (6.814%)
# Perplexity after injection:  1.8764
# Delta: 0.09%  (must be < 1% to proceed)
#
# Gate OK. Safe to proceed.

# %%
# ── CELL 6: Sandbox smoke tests ──
# Step 4 from README_PROTOTYPE.md.
# Tests: correct code, wrong code, timeout, HumanEval full parser, partial credit.

from sandbox import execute_code_safely, execute_humaneval

# Test 1: correct code → reward 1.0
good  = "def reverse_string(s):\n    return s[::-1]"
tests = [{"input": "reverse_string('hello')", "expected": "'olleh'"}]
r, _ = execute_code_safely(good, tests)
assert r == 1.0, f"Expected 1.0, got {r}"
print(f"  PASS correct code:     reward={r}")

# Test 2: wrong code → reward 0.0
wrong = "def reverse_string(s):\n    return s"
r2, _ = execute_code_safely(wrong, tests)
assert r2 == 0.0, f"Expected 0.0, got {r2}"
print(f"  PASS wrong code:       reward={r2}")

# Test 3: timeout → reward -0.1
loop  = "def reverse_string(s):\n    while True: pass"
r3, _ = execute_code_safely(loop, tests, timeout=2)
assert r3 == -0.1, f"Expected -0.1, got {r3}"
print(f"  PASS timeout:          reward={r3}")

# Test 4: HumanEval canonical check() parser
fake_problem = {
    "entry_point": "add",
    "test": (
        "def check(candidate):\n"
        "    assert candidate(1, 2) == 3\n"
        "    assert candidate(0, 0) == 0\n"
        "    assert candidate(-1, 1) == 0\n"
    )
}
r4, _ = execute_humaneval("def add(a, b):\n    return a + b", fake_problem)
assert r4 == 1.0, f"Expected 1.0, got {r4}"
print(f"  PASS HumanEval parser: reward={r4}")

# Test 5: partial credit
broken = "def add(a, b):\n    return abs(a) + abs(b)"  # fails the -1+1=0 test
r5, fb5 = execute_humaneval(broken, fake_problem)
assert 0.0 < r5 < 1.0, f"Expected partial credit, got {r5}"
print(f"  PASS partial credit:   reward={r5:.2f}")

print("\nAll sandbox tests passed.")
# Out:
#   PASS correct code:     reward=1.0
#   PASS wrong code:       reward=0.0
#   PASS timeout:          reward=-0.1
#   PASS HumanEval parser: reward=1.0
#   PASS partial credit:   reward=0.67
#
# All sandbox tests passed.

# %%
# ── CELL 7: Download HumanEval + calibration scan ──
# Step 5 from README_PROTOTYPE.md.
# Scans first 80 problems, keeps those with base model pass rate 30–60%.
# Runtime: ~20 min on T4. Reduce to raw_problems[:40] to go faster.

from eval import load_humaneval, calibrate_problem_difficulty

raw_problems = load_humaneval("/kaggle/working/problems/humaneval_raw.json")
print(f"Loaded {len(raw_problems)} raw HumanEval problems.")

calibrated = calibrate_problem_difficulty(
    model, tokenizer,
    problems=raw_problems[:100],
    n_attempts=3,
    target_range=(0.3, 0.7),
    save_path="/kaggle/working/problems/calibrated_20.json"
)
print(f"\nCalibrated set: {len(calibrated)} problems saved.")
# Out:
# Local file not found — downloading from HuggingFace datasets...
# README.md: 0.00B [00:00, ?B/s]
# openai_humaneval/test-00000-of-00001.par(…):   0%|          | 0.00/83.9k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/164 [00:00<?, ? examples/s]
# Saved 164 problems → /kaggle/working/problems/humaneval_raw.json
# Loaded 164 raw HumanEval problems.
# Calibrating 100 problems (target pass rate: 0.3–0.7)...
#
#   DROP HumanEval/0: too easy  (pass_rate=1.00)
#   DROP HumanEval/1: too easy  (pass_rate=1.00)
#   KEEP HumanEval/2: pass_rate=0.33
#   KEEP HumanEval/3: pass_rate=0.67
#   DROP HumanEval/4: too easy  (pass_rate=1.00)
#   KEEP HumanEval/5: pass_rate=0.33
#   DROP HumanEval/6: too hard  (pass_rate=0.00)
#   DROP HumanEval/7: too hard  (pass_rate=0.00)
#   KEEP HumanEval/8: pass_rate=0.67
#   DROP HumanEval/9: too easy  (pass_rate=1.00)
#   DROP HumanEval/10: too hard  (pass_rate=0.00)
#   DROP HumanEval/11: too easy  (pass_rate=1.00)
#   DROP HumanEval/12: too easy  (pass_rate=1.00)
#   KEEP HumanEval/13: pass_rate=0.67
#   KEEP HumanEval/14: pass_rate=0.33
#   DROP HumanEval/15: too easy  (pass_rate=1.00)
#   DROP HumanEval/16: too easy  (pass_rate=1.00)
#   DROP HumanEval/17: too hard  (pass_rate=0.00)
#   KEEP HumanEval/18: pass_rate=0.67
#   DROP HumanEval/19: too hard  (pass_rate=0.00)
#   DROP HumanEval/20: too hard  (pass_rate=0.00)
#   DROP HumanEval/21: too hard  (pass_rate=0.00)
#   DROP HumanEval/22: too easy  (pass_rate=1.00)
#   DROP HumanEval/23: too easy  (pass_rate=1.00)
#   KEEP HumanEval/24: pass_rate=0.67
#   DROP HumanEval/25: too easy  (pass_rate=1.00)
#   DROP HumanEval/26: too hard  (pass_rate=0.00)
#   DROP HumanEval/27: too easy  (pass_rate=1.00)
#   DROP HumanEval/28: too hard  (pass_rate=0.00)
#   KEEP HumanEval/29: pass_rate=0.33
#   DROP HumanEval/30: too easy  (pass_rate=1.00)
#   DROP HumanEval/31: too easy  (pass_rate=1.00)
#   DROP HumanEval/32: too hard  (pass_rate=0.00)
#   DROP HumanEval/33: too hard  (pass_rate=0.00)
#   DROP HumanEval/34: too easy  (pass_rate=1.00)
#   DROP HumanEval/35: too easy  (pass_rate=1.00)
#   DROP HumanEval/36: too hard  (pass_rate=0.00)
#   DROP HumanEval/37: too hard  (pass_rate=0.00)
#   DROP HumanEval/38: too hard  (pass_rate=0.00)
#   DROP HumanEval/39: too hard  (pass_rate=0.00)
#   DROP HumanEval/40: too hard  (pass_rate=0.00)
#   DROP HumanEval/41: too hard  (pass_rate=0.00)
#   DROP HumanEval/42: too easy  (pass_rate=1.00)
#   KEEP HumanEval/43: pass_rate=0.33
#   DROP HumanEval/44: too hard  (pass_rate=0.00)
#   DROP HumanEval/45: too easy  (pass_rate=1.00)
#   DROP HumanEval/46: too hard  (pass_rate=0.00)
#   DROP HumanEval/47: too easy  (pass_rate=1.00)
#   DROP HumanEval/48: too easy  (pass_rate=1.00)
#   KEEP HumanEval/49: pass_rate=0.33
#   DROP HumanEval/50: too hard  (pass_rate=0.00)
#   DROP HumanEval/51: too easy  (pass_rate=1.00)
#   DROP HumanEval/52: too hard  (pass_rate=0.00)
#   DROP HumanEval/53: too hard  (pass_rate=0.00)
#   KEEP HumanEval/54: pass_rate=0.67
#   DROP HumanEval/55: too easy  (pass_rate=1.00)
#   DROP HumanEval/56: too easy  (pass_rate=1.00)
#   DROP HumanEval/57: too easy  (pass_rate=1.00)
#   DROP HumanEval/58: too easy  (pass_rate=1.00)
#   DROP HumanEval/59: too hard  (pass_rate=0.00)
#   DROP HumanEval/60: too easy  (pass_rate=1.00)
#   DROP HumanEval/61: too easy  (pass_rate=1.00)
#   DROP HumanEval/62: too hard  (pass_rate=0.00)
#   DROP HumanEval/63: too hard  (pass_rate=0.00)
#   DROP HumanEval/64: too hard  (pass_rate=0.00)
#   DROP HumanEval/65: too hard  (pass_rate=0.00)
#   KEEP HumanEval/66: pass_rate=0.67
#   DROP HumanEval/67: too hard  (pass_rate=0.00)
#   DROP HumanEval/68: too easy  (pass_rate=1.00)
#   DROP HumanEval/69: too easy  (pass_rate=1.00)
#   DROP HumanEval/70: too hard  (pass_rate=0.00)
#   DROP HumanEval/71: too hard  (pass_rate=0.00)
#   DROP HumanEval/72: too easy  (pass_rate=1.00)
#   KEEP HumanEval/73: pass_rate=0.33
#   DROP HumanEval/74: too hard  (pass_rate=0.00)
#   DROP HumanEval/75: too hard  (pass_rate=0.00)
#   DROP HumanEval/76: too hard  (pass_rate=0.00)
#   DROP HumanEval/77: too hard  (pass_rate=0.00)
#   DROP HumanEval/78: too easy  (pass_rate=1.00)
#   DROP HumanEval/79: too easy  (pass_rate=1.00)
#   DROP HumanEval/80: too hard  (pass_rate=0.00)
#   DROP HumanEval/81: too hard  (pass_rate=0.00)
#   DROP HumanEval/82: too hard  (pass_rate=0.00)
#   DROP HumanEval/83: too hard  (pass_rate=0.00)
#   DROP HumanEval/84: too hard  (pass_rate=0.00)
#   DROP HumanEval/85: too hard  (pass_rate=0.00)
#   DROP HumanEval/86: too easy  (pass_rate=1.00)
#   DROP HumanEval/87: too hard  (pass_rate=0.00)
#   DROP HumanEval/88: too hard  (pass_rate=0.00)
#   KEEP HumanEval/89: pass_rate=0.67
#   DROP HumanEval/90: too hard  (pass_rate=0.00)
#   DROP HumanEval/91: too hard  (pass_rate=0.00)
#   DROP HumanEval/92: too hard  (pass_rate=0.00)
#   KEEP HumanEval/93: pass_rate=0.33
#   DROP HumanEval/94: too hard  (pass_rate=0.00)
#   DROP HumanEval/95: too hard  (pass_rate=0.00)
#   DROP HumanEval/96: too hard  (pass_rate=0.00)
#   DROP HumanEval/97: too easy  (pass_rate=1.00)
#   DROP HumanEval/98: too easy  (pass_rate=1.00)
#   DROP HumanEval/99: too hard  (pass_rate=0.00)
#
# Calibrated set: 16 / 100 problems
# Saved calibrated set → /kaggle/working/problems/calibrated_20.json
#
# Calibrated set: 16 problems saved.

# %%
# ── CELL 8: 3-problem smoke session ──
# Runs 1 full session on 3 problems to verify the loop end-to-end.
# Gate: .pt checkpoint file must appear in memory_states/smoke_test/

from session_manager import SessionManager

mgr = SessionManager(model, tokenizer, memory_modules, user_id="smoke_test")
summary = mgr.run_session(calibrated[:3])

print(json.dumps(summary, indent=2, default=str))

# Verify checkpoint was written
checkpoints = list(Path("/kaggle/working/memory_states/smoke_test").glob("memory_*.pt"))
assert checkpoints, "No checkpoint found — SessionManager.save() failed!"
print(f"\nCheckpoint written: {checkpoints[-1].name}  ✓")
# Out:
# No prior memory state. Starting fresh.
#   [FAIL] HumanEval/2: reward=0.00
#   [PASS] HumanEval/3: reward=1.00
#   [FAIL] HumanEval/5: reward=0.00
# Memory saved: memory_20260526_101241.pt
#
# Session complete: 33.3% (1/3)
# Log: session_20260526_101242.json
# {
#   "pass_rate": 0.3333,
#   "n_passed": 1,
#   "n_total": 3,
#   "results": [
#     {
#       "problem_id": "HumanEval/2",
#       "reward": 0.0,
#       "passed": false,
#       "feedback": "SyntaxError: invalid syntax (<unknown>, line 13)"
#     },
#     {
#       "problem_id": "HumanEval/3",
#       "reward": 1.0,
#       "passed": true,
#       "feedback": "Result for [1, 2, 3]: False\nResult for [1, 2, -4, 5]: True\n  Assert 1/6: PASS\n  Assert 2/6: PASS\n  Assert 3/6: PASS\n  Assert 4/6: PASS\n  Assert 5/6: PASS\n  Assert 6/6: PASS\n\u2192 6/6 assertions passed (reward=1.00)"
#     },
#     {
#       "problem_id": "HumanEval/5",
#       "reward": 0.0,
#       "passed": false,
#       "feedback": "SyntaxError: invalid syntax (<unknown>, line 12)"
#     }
#   ],
#   "memory_checkpoint": "memory_states/smoke_test/memory_20260526_101241.pt"
# }
#
# Checkpoint written: memory_20260526_101241.pt  ✓

# %%
# ── CELL 9: Full 5-session evaluation ──
# The main experiment. Runtime: ~2–4 hours on Kaggle P100.
# Target: improvement-on-failed-problems > 30% by session 5.
# Baseline (no memory): ~5%.

from eval import run_evaluation

all_results = run_evaluation(
    model, tokenizer, memory_modules,
    n_sessions=5,
    user_id="eval_memory",
    output_dir="/kaggle/working/results/",
    problems_path="/kaggle/working/problems/calibrated_20.json"
)
# Out:
# ==================================================
# SESSION 1/5
# ==================================================
# No prior memory state. Starting fresh.
#   [FAIL] HumanEval/2: reward=0.00
#   [PASS] HumanEval/3: reward=1.00
#   [PASS] HumanEval/5: reward=1.00
#   [PASS] HumanEval/8: reward=1.00
#   [PASS] HumanEval/13: reward=1.00
#   [FAIL] HumanEval/14: reward=0.00
#   [PASS] HumanEval/18: reward=1.00
#   [FAIL] HumanEval/24: reward=0.00
#   [FAIL] HumanEval/29: reward=0.00
#   [PASS] HumanEval/43: reward=1.00
#   [FAIL] HumanEval/49: reward=0.14
#   [PASS] HumanEval/54: reward=1.00
#   [FAIL] HumanEval/66: reward=0.30
#   [PASS] HumanEval/73: reward=1.00
#   [PASS] HumanEval/89: reward=1.00
#   [FAIL] HumanEval/93: reward=0.00
# Memory saved: memory_20260526_102317.pt
#
# Session complete: 56.2% (9/16)
# Log: session_20260526_102318.json
#
# ── Memory Diagnostics ──
#   Layer 4: weight_norm=1.1004
#   Layer 8: weight_norm=1.6572
#   Layer 16: weight_norm=1.1048
#   Layer 24: weight_norm=8.1686
#
# ==================================================
# SESSION 2/5
# ==================================================
# Loaded memory: memory_20260526_102317.pt
#   [FAIL] HumanEval/2: reward=0.00
#   [FAIL] HumanEval/3: reward=0.00
#   [PASS] HumanEval/5: reward=1.00
#   [PASS] HumanEval/8: reward=1.00
#   [PASS] HumanEval/13: reward=1.00
#   [FAIL] HumanEval/14: reward=0.00
#   [PASS] HumanEval/18: reward=1.00
#   [FAIL] HumanEval/24: reward=0.00
#   [FAIL] HumanEval/29: reward=0.00
#   [FAIL] HumanEval/43: reward=0.56
#   [FAIL] HumanEval/49: reward=0.29
#   [PASS] HumanEval/54: reward=1.00
#   [PASS] HumanEval/66: reward=1.00
#   [FAIL] HumanEval/73: reward=0.50
#   [PASS] HumanEval/89: reward=1.00
#   [PASS] HumanEval/93: reward=1.00
# Memory saved: memory_20260526_103301.pt
#
# Session complete: 50.0% (8/16)
# Log: session_20260526_103302.json
#
# ── Memory Diagnostics ──
#   Layer 4: weight_norm=0.3630
#   Layer 8: weight_norm=2.5445
#   Layer 16: weight_norm=2.1947
#   Layer 24: weight_norm=8.2999
#
# ==================================================
# SESSION 3/5
# ==================================================
# Loaded memory: memory_20260526_103301.pt
#   [FAIL] HumanEval/2: reward=0.00
#   [PASS] HumanEval/3: reward=1.00
#   [FAIL] HumanEval/5: reward=0.00
#   [PASS] HumanEval/8: reward=1.00
#   [PASS] HumanEval/13: reward=1.00
#   [FAIL] HumanEval/14: reward=0.00
#   [PASS] HumanEval/18: reward=1.00
#   [FAIL] HumanEval/24: reward=0.00
#   [PASS] HumanEval/29: reward=1.00
#   [FAIL] HumanEval/43: reward=0.67
#   [FAIL] HumanEval/49: reward=0.14
#   [PASS] HumanEval/54: reward=1.00
#   [PASS] HumanEval/66: reward=1.00
#   [FAIL] HumanEval/73: reward=0.00
#   [PASS] HumanEval/89: reward=1.00
#   [PASS] HumanEval/93: reward=1.00
# Memory saved: memory_20260526_104251.pt
#
# Session complete: 56.2% (9/16)
# Log: session_20260526_104252.json
#
# ── Memory Diagnostics ──
#   Layer 4: weight_norm=0.4876
#   Layer 8: weight_norm=2.1028
#   Layer 16: weight_norm=2.2589
#   Layer 24: weight_norm=8.1946
#
# ==================================================
# SESSION 4/5
# ==================================================
# Loaded memory: memory_20260526_104251.pt
#   [FAIL] HumanEval/2: reward=0.00
#   [PASS] HumanEval/3: reward=1.00
#   [PASS] HumanEval/5: reward=1.00
#   [PASS] HumanEval/8: reward=1.00
#   [PASS] HumanEval/13: reward=1.00
#   [FAIL] HumanEval/14: reward=0.00
#   [PASS] HumanEval/18: reward=1.00
#   [PASS] HumanEval/24: reward=1.00
#   [PASS] HumanEval/29: reward=1.00
#   [PASS] HumanEval/43: reward=1.00
#   [FAIL] HumanEval/49: reward=0.29
#   [PASS] HumanEval/54: reward=1.00
#   [PASS] HumanEval/66: reward=1.00
#   [FAIL] HumanEval/73: reward=0.88
#   [PASS] HumanEval/89: reward=1.00
#   [FAIL] HumanEval/93: reward=0.00
# Memory saved: memory_20260526_105302.pt
#
# Session complete: 68.8% (11/16)
# Log: session_20260526_105303.json
#
# ── Memory Diagnostics ──
#   Layer 4: weight_norm=2.4409
#   Layer 8: weight_norm=1.5706
#   Layer 16: weight_norm=2.1413
#   Layer 24: weight_norm=11.0477
#
# ==================================================
# SESSION 5/5
# ==================================================
# Loaded memory: memory_20260526_105302.pt
#   [FAIL] HumanEval/2: reward=0.00
#   [PASS] HumanEval/3: reward=1.00
#   [PASS] HumanEval/5: reward=1.00
#   [PASS] HumanEval/8: reward=1.00
#   [PASS] HumanEval/13: reward=1.00
#   [FAIL] HumanEval/14: reward=0.00
#   [PASS] HumanEval/18: reward=1.00
#   [PASS] HumanEval/24: reward=1.00
#   [PASS] HumanEval/29: reward=1.00
#   [FAIL] HumanEval/43: reward=0.56
#   [PASS] HumanEval/49: reward=1.00
#   [PASS] HumanEval/54: reward=1.00
#   [PASS] HumanEval/66: reward=1.00
#   [FAIL] HumanEval/73: reward=0.50
#   [PASS] HumanEval/89: reward=1.00
#   [PASS] HumanEval/93: reward=1.00
# Memory saved: memory_20260526_110320.pt
#
# Session complete: 75.0% (12/16)
# Log: session_20260526_110320.json
#
# ── Memory Diagnostics ──
#   Layer 4: weight_norm=1.9831
#   Layer 8: weight_norm=1.8841
#   Layer 16: weight_norm=1.9987
#   Layer 24: weight_norm=12.3435
#
# Session    Pass%      vs S1
# ───────────────────────────────────
# 1          56.2      % +0.0%
# 2          50.0      % -6.2%
# 3          56.2      % +0.0%
# 4          68.8      % +12.5%
# 5          75.0      % +18.8%
#
# Improvement on previously-failed problems: 71.4%  (n=7)
# Baseline/no-memory target: ~5%  |  Memory model target: >30%
#
# Full results saved → /kaggle/working/results/eval_eval_memory_results.json

# %%
# ── CELL 10: Zip checkpoint + results for download ──
# Kaggle sessions expire. Run this BEFORE closing the notebook.
# Download memory_checkpoint.zip from the Output panel on the right.

import zipfile

ZIP_PATH = "/kaggle/working/memory_checkpoint.zip"

with zipfile.ZipFile(ZIP_PATH, "w", zipfile.ZIP_DEFLATED) as zf:
    for folder in ["memory_states", "results", "problems"]:
        root = f"/kaggle/working/{folder}"
        for dirpath, _, files in os.walk(root):
            for file in files:
                fpath = os.path.join(dirpath, file)
                zf.write(fpath, os.path.relpath(fpath, "/kaggle/working"))

size_mb = os.path.getsize(ZIP_PATH) / 1e6
print(f"Zipped → {ZIP_PATH}  ({size_mb:.1f} MB)")
print("Download via: Output panel → memory_checkpoint.zip → Download")
# Out:
# Zipped → /kaggle/working/memory_checkpoint.zip  (904.5 MB)
# Download via: Output panel → memory_checkpoint.zip → Download
